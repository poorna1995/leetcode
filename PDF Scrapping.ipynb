# %%
pip install PyPDF2

# %%
 # importing required modules 
import PyPDF2 



with open('poorna.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    pdf_text = ""
    for page in reader.pages:
        pdf_text += page.extract_text()

print(pdf_text)
# Out:
# ”POORNA” PRANEESHA D
# (+91) 8985 650250 ⋄poorna7d@gmail.com.
# Linkedin ⋄GitHub ⋄Design Portfolio ⋄Website
# A Lead full-stack Software engineer and designer and a creative thinker with 6+ years of industrial experience. Strongly
# driven towards creating value for business and technology stakeholders, bringing design innovation to the product. Worked
# in diverse domains ranging from E-Commerce, Consumer Technology, Finance, Networking, Construction and entertainment
# Industries. Experience in building end-to-end UI/UX design teams, grow and mentor.
# Areas of Interests - HumanAI, Augmented and Virtual Reality (AR/VR), Machine Learning
# Core Skills - Project Building, Cross-Functional Collaboration, Market and Competitors Analysis, User -Centred Design,
# Leadership Communication, Technical Acumen, Agile Methodologies, Decision Making
# EDUCATION
# Sri Venkateswara University, India 2013 - 2017
# B.Tech. Major in Chemical Engineering — Minor in Computer Engineering
# ...
